# %% [markdown]
# # Spark DataFrames Project Exercise

# %% [markdown]
# Let's get some quick practice with your new Spark DataFrame skills, you will be asked some basic questions about some stock market data, in this case Walmart Stock from the years 2012-2017. This exercise will just ask a bunch of questions, unlike the future machine learning exercises, which will be a little looser and be in the form of "Consulting Projects", but more on that later!
#
# For now, just answer the questions and complete the tasks below.

# %% [markdown]
# #### Use the walmart_stock.csv file to Answer and complete the  tasks below!

# %% [markdown]
# #### Start a simple Spark Session

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# #### Load the Walmart Stock CSV File, have Spark infer the data types.

# %%
spark = SparkSession.builder.appName('Walmart').getOrCreate()
df = spark.read.csv('walmart_stock.csv', header=True, inferSchema=True)

# %%
df.show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+--------+------------------+
# |               Date|              Open|              High|               Low|             Close|  Volume|         Adj Close|
# +-------------------+------------------+------------------+------------------+------------------+--------+------------------+
# |2012-01-03 00:00:00|         59.970001|         61.060001|         59.869999|         60.330002|12668800|52.619234999999996|
# |2012-01-04 00:00:00|60.209998999999996|         60.349998|         59.470001|59.709998999999996| 9593300|         52.078475|
# |2012-01-05 00:00:00|         59.349998|         59.619999|         58.369999|         59.419998|12768200|         51.825539|
# |2012-01-06 00:00:00|         59.419998|         59.450001|         58.869999|              59.0| 8069400|          51.45922|
# |2012-01-09 00:00:00|         59.029999|         59.549999|         58.919998|             59.18| 6679300|51.616215000000004|
# |2012-01-10 00:00:00|             59.43|59.709998999999996|             58.98|59.040001000000004| 6907300|         51.494109|
# |2012-01-11 00:00:00|         59.060001|         59.529999|59.040001000000004|         59.400002| 6365600|         51.808098|
# |2012-01-12 00:00:00|59.790001000000004|              60.0|         59.400002|              59.5| 7236400|51.895315999999994|
# |2012-01-13 00:00:00|             59.18|59.610001000000004|59.009997999999996|59.540001000000004| 7729300|51.930203999999996|
# |2012-01-17 00:00:00|         59.869999|60.110001000000004|             59.52|         59.849998| 8500000|         52.200581|
# |2012-01-18 00:00:00|59.790001000000004|         60.029999|         59.650002|60.009997999999996| 5911400|         52.340131|
# |2012-01-19 00:00:00|             59.93|             60.73|             59.75|60.610001000000004| 9234600|         52.863447|
# |2012-01-20 00:00:00|             60.75|             61.25|         60.669998|61.009997999999996|10378800|53.212320999999996|
# |2012-01-23 00:00:00|         60.810001|             60.98|60.509997999999996|             60.91| 7134100|         53.125104|
# |2012-01-24 00:00:00|             60.75|              62.0|             60.75|61.389998999999996| 7362800| 53.54375400000001|
# |2012-01-25 00:00:00|             61.18|61.610001000000004|61.040001000000004|         61.470001| 5915800| 53.61353100000001|
# |2012-01-26 00:00:00|         61.799999|             61.84|             60.77|         60.970001| 7436200|         53.177436|
# |2012-01-27 00:00:00|60.860001000000004|         61.119999|60.540001000000004|60.709998999999996| 6287300|         52.950665|
# |2012-01-30 00:00:00|         60.470001|             61.32|         60.349998|         61.299999| 7636900|53.465256999999994|
# |2012-01-31 00:00:00|         61.529999|             61.57|         60.580002|61.360001000000004| 9761500|53.517590000000006|
# +-------------------+------------------+------------------+------------------+------------------+--------+------------------+
# only showing top 20 rows

# %% [markdown]
# #### What are the column names?

# %%
df.columns
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close']

# %% [markdown]
# #### What does the Schema look like?

# %%
df.printSchema()
# Out:
# root
#  |-- Date: timestamp (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Volume: integer (nullable = true)
#  |-- Adj Close: double (nullable = true)

# %% [markdown]
# #### Print out the first 5 columns.

# %%
df.head(5)
# Out:
# [Row(Date=datetime.datetime(2012, 1, 3, 0, 0), Open=59.970001, High=61.060001, Low=59.869999, Close=60.330002, Volume=12668800, Adj Close=52.619234999999996),
#  Row(Date=datetime.datetime(2012, 1, 4, 0, 0), Open=60.209998999999996, High=60.349998, Low=59.470001, Close=59.709998999999996, Volume=9593300, Adj Close=52.078475),
#  Row(Date=datetime.datetime(2012, 1, 5, 0, 0), Open=59.349998, High=59.619999, Low=58.369999, Close=59.419998, Volume=12768200, Adj Close=51.825539),
#  Row(Date=datetime.datetime(2012, 1, 6, 0, 0), Open=59.419998, High=59.450001, Low=58.869999, Close=59.0, Volume=8069400, Adj Close=51.45922),
#  Row(Date=datetime.datetime(2012, 1, 9, 0, 0), Open=59.029999, High=59.549999, Low=58.919998, Close=59.18, Volume=6679300, Adj Close=51.616215000000004)]

# %% [markdown]
# #### Use describe() to learn about the DataFrame.

# %%
df.describe().show()
# Out:
# +-------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# |summary|              Open|             High|              Low|            Close|           Volume|        Adj Close|
# +-------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# |  count|              1258|             1258|             1258|             1258|             1258|             1258|
# |   mean| 72.35785375357709|72.83938807631165| 71.9186009594594|72.38844998012726|8222093.481717011|67.23883848728146|
# | stddev|  6.76809024470826|6.768186808159218|6.744075756255496|6.756859163732991|  4519780.8431556|6.722609449996857|
# |    min|56.389998999999996|        57.060001|        56.299999|        56.419998|          2094900|        50.363689|
# |    max|         90.800003|        90.970001|            89.25|        90.470001|         80898100|84.91421600000001|
# +-------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+

# %% [markdown]
# ## Bonus Question!
# #### There are too many decimal places for mean and stddev in the describe() dataframe. Format the numbers to just show up to two decimal places. Pay careful attention to the datatypes that .describe() returns, we didn't cover how to do this exact formatting, but we covered something very similar. [Check this link for a hint](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.Column.cast)
#
# If you get stuck on this, don't worry, just view the solutions.

# %%
# cast datatype
type(df.select(df.Open.cast("string")).collect()[1][0]) #string
type(df.select(df.Open.cast("int")).collect()[1][0]) #integer
# Out:
# str

# %%
df.describe().printSchema()
# Out:
# root
#  |-- summary: string (nullable = true)
#  |-- Open: string (nullable = true)
#  |-- High: string (nullable = true)
#  |-- Low: string (nullable = true)
#  |-- Close: string (nullable = true)
#  |-- Volume: string (nullable = true)
#  |-- Adj Close: string (nullable = true)

# %%
from pyspark.sql.functions import format_number
# columns ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close']
# columns = df.columns.remove('Date')
columns = df.columns
columns.remove('Date')
# Out:
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close']

# %%
for col in columns:
    df.select(df[col].cast("int"))
    print(col, type(col))
# Out:
# Open <class 'str'>
# High <class 'str'>
# Low <class 'str'>
# Close <class 'str'>
# Volume <class 'str'>
# Adj Close <class 'str'>

# %%
df.select(format_number((df["High"].cast("float")),2)).collect()
# Out:
# [Row(format_number(CAST(High AS FLOAT), 2)='61.06'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.35'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.62'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.45'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.55'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.71'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.53'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.61'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.11'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.03'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.73'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.61'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.84'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.32'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.57'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.63'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.47'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.43'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.02'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.16'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.91'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.08'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.19'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.57'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.78'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.10'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.33'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.42'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.28'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.59'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.22'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.08'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.15'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.26'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.47'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.88'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.72'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.77'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.85'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.32'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.48'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.42'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.41'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.59'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.34'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.39'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.29'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.21'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.81'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.05'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.35'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.43'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.43'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.46'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.99'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.27'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.32'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.18'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.36'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.61'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.55'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.66'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='62.63'),
#  Row(format_number(CAST(High AS FLOAT), 2)='63.10'),
#  Row(format_number(CAST(High AS FLOAT), 2)='63.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.18'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.76'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='66.66'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.88'),
#  Row(format_number(CAST(High AS FLOAT), 2)='66.13'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.97'),
#  Row(format_number(CAST(High AS FLOAT), 2)='66.08'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.48'),
#  Row(format_number(CAST(High AS FLOAT), 2)='67.85'),
#  Row(format_number(CAST(High AS FLOAT), 2)='67.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='67.79'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.06'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.28'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.54'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.66'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.35'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.92'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.35'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.72'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.77'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.30'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.36'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.76'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.58'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.62'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.18'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.10'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.46'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.99'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.46'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.80'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.79'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.16'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.92'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.60'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.51'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.52'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.27'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.52'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.41'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.34'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.85'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.79'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.71'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.02'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.84'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.81'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.80'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.42'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.35'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.19'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.99'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.68'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.17'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.63'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.82'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.09'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.05'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.84'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.06'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.36'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.01'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.55'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.38'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.81'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.61'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.04'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.35'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.60'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.71'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.78'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.42'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.68'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.16'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.57'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.28'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.60'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.60'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.30'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.13'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.06'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.17'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.81'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.04'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.34'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.60'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.02'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.85'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.59'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.34'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.70'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.35'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.36'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.30'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.51'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.66'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.06'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.16'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.81'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.42'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.35'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.30'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.35'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.18'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.92'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.89'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.71'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.03'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.79'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.67'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.32'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.64'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.99'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.54'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.07'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.32'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.64'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.64'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.51'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.66'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.70'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.45'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.85'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.47'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.54'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.34'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.39'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.88'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.26'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.04'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.13'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.61'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.39'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.73'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.87'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.38'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.47'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.29'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.11'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.09'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.97'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.93'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.05'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.68'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.58'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.41'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.45'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.46'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.38'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.85'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.28'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.07'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.05'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.22'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.83'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.15'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.30'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.66'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.34'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.16'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.14'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.66'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.91'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.59'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.18'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.80'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.41'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.04'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.05'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.54'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.63'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.80'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.38'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.74'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.87'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.83'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.71'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.33'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.27'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.45'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.88'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.66'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.79'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.18'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.11'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.66'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.28'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.68'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.26'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.77'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.67'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.30'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.45'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.79'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.55'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.17'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.63'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.46'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.03'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.36'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.48'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.67'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.57'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.63'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.89'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.32'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.39'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.22'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.08'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.93'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.62'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.13'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.03'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.11'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.88'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.07'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.58'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.48'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.16'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.21'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.52'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.40'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.19'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.47'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.53'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.53'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.45'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.43'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.73'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.46'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.60'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.89'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.72'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.53'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.38'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.42'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.19'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.34'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.87'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.83'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.71'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.62'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.93'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.82'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.35'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.51'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.76'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.21'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.63'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.53'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.15'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.40'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.61'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.28'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.22'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.07'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.97'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.99'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.53'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.29'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.32'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.35'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.39'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.87'),
#  Row(format_number(CAST(High AS FLOAT), 2)='80.57'),
#  Row(format_number(CAST(High AS FLOAT), 2)='80.68'),
#  Row(format_number(CAST(High AS FLOAT), 2)='81.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='81.35'),
#  Row(format_number(CAST(High AS FLOAT), 2)='81.28'),
#  Row(format_number(CAST(High AS FLOAT), 2)='81.33'),
#  Row(format_number(CAST(High AS FLOAT), 2)='81.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.77'),
#  Row(format_number(CAST(High AS FLOAT), 2)='80.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='80.43'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.80'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.72'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.26'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.77'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.89'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.83'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.88'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.99'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.24'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.52'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.93'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.88'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.87'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.47'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.13'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.91'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.85'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.51'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.40'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.72'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.97'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.10'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.47'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.82'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.39'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.08'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.40'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.09'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.19'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.10'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.16'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.21'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.80'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.76'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.85'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.18'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.99'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.32'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.40'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.82'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.74'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.10'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.78'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.19'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.67'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.33'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.11'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.60'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.97'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.18'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.07'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.85'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.99'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.11'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.68'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.02'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.80'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.14'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.53'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.82'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.60'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.78'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.19'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.55'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.72'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.31'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.22'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.14'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.55'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.31'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.47'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.73'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.83'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.28'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.47'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.78'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.99'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.87'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.93'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.73'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.76'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.39'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.10'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.83'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.28'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.05'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.38'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.13'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.92'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.81'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.19'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.81'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.11'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.97'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.30'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.59'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.76'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.74'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.19'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.76'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.48'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.42'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.28'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.17'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.21'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.84'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.61'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.38'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.42'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.05'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.21'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.33'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.57'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.97'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.93'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.05'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.05'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.10'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.91'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.89'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.06'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.79'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.36'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.93'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.01'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.92'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.88'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.63'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.52'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.29'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.81'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.73'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.60'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.41'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.43'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.68'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.05'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.91'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.02'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.15'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.88'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.33'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.60'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.73'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.32'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.08'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.05'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.89'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.57'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.47'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.58'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.07'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.22'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.31'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.05'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.57'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.72'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.91'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.48'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.92'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.83'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.58'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.63'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.07'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.22'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.66'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.80'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.64'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.60'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.40'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.38'),
#  Row(format_number(CAST(High AS FLOAT), 2)='77.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.18'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.08'),
#  Row(format_number(CAST(High AS FLOAT), 2)='80.13'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.42'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.06'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.15'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.72'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.92'),
#  Row(format_number(CAST(High AS FLOAT), 2)='85.64'),
#  Row(format_number(CAST(High AS FLOAT), 2)='85.29'),
#  Row(format_number(CAST(High AS FLOAT), 2)='85.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='85.61'),
#  Row(format_number(CAST(High AS FLOAT), 2)='85.51'),
#  Row(format_number(CAST(High AS FLOAT), 2)='85.11'),
#  Row(format_number(CAST(High AS FLOAT), 2)='88.09'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.07'),
#  Row(format_number(CAST(High AS FLOAT), 2)='86.70'),
#  Row(format_number(CAST(High AS FLOAT), 2)='86.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.82'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.82'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.67'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.21'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.31'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='85.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.70'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.76'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.26'),
#  Row(format_number(CAST(High AS FLOAT), 2)='85.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='86.34'),
#  Row(format_number(CAST(High AS FLOAT), 2)='86.40'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.08'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.07'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.14'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.07'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.13'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='86.72'),
#  Row(format_number(CAST(High AS FLOAT), 2)='86.32'),
#  Row(format_number(CAST(High AS FLOAT), 2)='86.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='88.68'),
#  Row(format_number(CAST(High AS FLOAT), 2)='90.67'),
#  Row(format_number(CAST(High AS FLOAT), 2)='90.39'),
#  Row(format_number(CAST(High AS FLOAT), 2)='90.31'),
#  Row(format_number(CAST(High AS FLOAT), 2)='90.97'),
#  Row(format_number(CAST(High AS FLOAT), 2)='88.52'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.78'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.46'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.70'),
#  Row(format_number(CAST(High AS FLOAT), 2)='86.91'),
#  Row(format_number(CAST(High AS FLOAT), 2)='88.40'),
#  Row(format_number(CAST(High AS FLOAT), 2)='89.26'),
#  Row(format_number(CAST(High AS FLOAT), 2)='89.16'),
#  Row(format_number(CAST(High AS FLOAT), 2)='88.46'),
#  Row(format_number(CAST(High AS FLOAT), 2)='88.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.72'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.36'),
#  Row(format_number(CAST(High AS FLOAT), 2)='85.87'),
#  Row(format_number(CAST(High AS FLOAT), 2)='86.53'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.04'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.36'),
#  Row(format_number(CAST(High AS FLOAT), 2)='88.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.19'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.41'),
#  Row(format_number(CAST(High AS FLOAT), 2)='87.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='86.68'),
#  Row(format_number(CAST(High AS FLOAT), 2)='86.16'),
#  Row(format_number(CAST(High AS FLOAT), 2)='85.97'),
#  Row(format_number(CAST(High AS FLOAT), 2)='86.30'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.80'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.38'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.82'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.72'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.16'),
#  Row(format_number(CAST(High AS FLOAT), 2)='84.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.82'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.21'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.87'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.10'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.34'),
#  Row(format_number(CAST(High AS FLOAT), 2)='82.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='81.97'),
#  Row(format_number(CAST(High AS FLOAT), 2)='82.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='82.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.01'),
#  Row(format_number(CAST(High AS FLOAT), 2)='82.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='82.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.71'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='82.31'),
#  Row(format_number(CAST(High AS FLOAT), 2)='82.18'),
#  Row(format_number(CAST(High AS FLOAT), 2)='82.80'),
#  Row(format_number(CAST(High AS FLOAT), 2)='83.04'),
#  Row(format_number(CAST(High AS FLOAT), 2)='82.28'),
#  Row(format_number(CAST(High AS FLOAT), 2)='81.32'),
#  Row(format_number(CAST(High AS FLOAT), 2)='81.33'),
#  Row(format_number(CAST(High AS FLOAT), 2)='81.29'),
#  Row(format_number(CAST(High AS FLOAT), 2)='81.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='81.39'),
#  Row(format_number(CAST(High AS FLOAT), 2)='81.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='80.92'),
#  Row(format_number(CAST(High AS FLOAT), 2)='80.42'),
#  Row(format_number(CAST(High AS FLOAT), 2)='80.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.89'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.15'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.83'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.84'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.64'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.54'),
#  Row(format_number(CAST(High AS FLOAT), 2)='80.93'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.48'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.79'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.48'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.76'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.55'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.01'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.34'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.61'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.48'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.43'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.77'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.25'),
#  Row(format_number(CAST(High AS FLOAT), 2)='79.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='78.36'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.42'),
#  Row(format_number(CAST(High AS FLOAT), 2)='76.38'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.83'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.51'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.16'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.88'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.08'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='75.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.27'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.85'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.33'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.67'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.40'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.58'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.48'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.22'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.19'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.63'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.46'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.81'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.56'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.86'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.59'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.73'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.55'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.11'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.09'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.14'),
#  Row(format_number(CAST(High AS FLOAT), 2)='74.07'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.29'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.82'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.22'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.56'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.39'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.63'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.53'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.38'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.80'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='73.38'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.83'),
#  Row(format_number(CAST(High AS FLOAT), 2)='71.75'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.37'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.66'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.77'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.60'),
#  Row(format_number(CAST(High AS FLOAT), 2)='72.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='70.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.39'),
#  Row(format_number(CAST(High AS FLOAT), 2)='69.30'),
#  Row(format_number(CAST(High AS FLOAT), 2)='68.31'),
#  Row(format_number(CAST(High AS FLOAT), 2)='66.16'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.71'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.85'),
#  Row(format_number(CAST(High AS FLOAT), 2)='66.18'),
#  Row(format_number(CAST(High AS FLOAT), 2)='66.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.32'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.01'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.30'),
#  Row(format_number(CAST(High AS FLOAT), 2)='66.50'),
#  Row(format_number(CAST(High AS FLOAT), 2)='67.01'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.68'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.67'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.70'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.77'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.29'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.23'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='63.82'),
#  Row(format_number(CAST(High AS FLOAT), 2)='63.93'),
#  Row(format_number(CAST(High AS FLOAT), 2)='63.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.46'),
#  Row(format_number(CAST(High AS FLOAT), 2)='63.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.04'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='64.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.92'),
#  Row(format_number(CAST(High AS FLOAT), 2)='65.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='66.36'),
#  Row(format_number(CAST(High AS FLOAT), 2)='66.99'),
#  Row(format_number(CAST(High AS FLOAT), 2)='67.02'),
#  Row(format_number(CAST(High AS FLOAT), 2)='67.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='66.94'),
#  Row(format_number(CAST(High AS FLOAT), 2)='67.95'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.47'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.30'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.00'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.04'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.96'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.28'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.45'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.04'),
#  Row(format_number(CAST(High AS FLOAT), 2)='57.72'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.12'),
#  Row(format_number(CAST(High AS FLOAT), 2)='57.61'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.33'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.76'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.98'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.20'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.78'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.71'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.73'),
#  Row(format_number(CAST(High AS FLOAT), 2)='57.77'),
#  Row(format_number(CAST(High AS FLOAT), 2)='57.06'),
#  Row(format_number(CAST(High AS FLOAT), 2)='58.03'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.90'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.07'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.36'),
#  Row(format_number(CAST(High AS FLOAT), 2)='61.47'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.74'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.42'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.71'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.69'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.06'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.29'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.29'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.66'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.85'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.73'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.49'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.11'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.09'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.53'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.44'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.84'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.65'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.33'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.40'),
#  Row(format_number(CAST(High AS FLOAT), 2)='59.58'),
#  Row(format_number(CAST(High AS FLOAT), 2)='60.70'),
#  ...]

# %% [markdown]
# #### Create a new dataframe with a column called HV Ratio that is the ratio of the High Price versus volume of stock traded for a day.

# %%
# Out:
# +--------------------+
# |            HV Ratio|
# +--------------------+
# |4.819714653321546E-6|
# |6.290848613094555E-6|
# |4.669412994783916E-6|
# |7.367338463826307E-6|
# |8.915604778943901E-6|
# |8.644477436914568E-6|
# |9.351828421515645E-6|
# | 8.29141562102703E-6|
# |7.712212102001476E-6|
# |7.071764823529412E-6|
# |1.015495466386981E-5|
# |6.576354146362592...|
# | 5.90145296180676E-6|
# |8.547679455011844E-6|
# |8.420709512685392E-6|
# |1.041448341728929...|
# |8.316075414862431E-6|
# |9.721183814992126E-6|
# |8.029436027707578E-6|
# |6.307432259386365E-6|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# #### What day had the Peak High in Price?

# %%
# Out:
# datetime.datetime(2015, 1, 13, 0, 0)

# %% [markdown]
# #### What is the mean of the Close column?

# %%
# Out:
# +-----------------+
# |       avg(Close)|
# +-----------------+
# |72.38844998012726|
# +-----------------+

# %% [markdown]
# #### What is the max and min of the Volume column?

# %%
# Out:
# +-----------+-----------+
# |max(Volume)|min(Volume)|
# +-----------+-----------+
# |   80898100|    2094900|
# +-----------+-----------+

# %% [markdown]
# #### How many days was the Close lower than 60 dollars?

# %%
# Out:
# 81

# %% [markdown]
# #### What percentage of the time was the High greater than 80 dollars ?
# #### In other words, (Number of Days High>80)/(Total Days in the dataset)

# %%
# Out:
# 9.141494435612083

# %% [markdown]
# #### What is the Pearson correlation between High and Volume?
# #### [Hint](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrameStatFunctions.corr)

# %%
# Out:
# +-------------------+
# | corr(High, Volume)|
# +-------------------+
# |-0.3384326061737161|
# +-------------------+

# %% [markdown]
# #### What is the max High per year?

# %%
# Out:
# +----+---------+
# |Year|max(High)|
# +----+---------+
# |2015|90.970001|
# |2013|81.370003|
# |2014|88.089996|
# |2012|77.599998|
# |2016|75.190002|
# +----+---------+

# %% [markdown]
# #### What is the average Close for each Calendar Month?
# #### In other words, across all the years, what is the average Close price for Jan,Feb, Mar, etc... Your result will have a value for each of these months.

# %%
# Out:
# +-----+-----------------+
# |Month|       avg(Close)|
# +-----+-----------------+
# |    1|71.44801958415842|
# |    2|  71.306804443299|
# |    3|71.77794377570092|
# |    4|72.97361900952382|
# |    5|72.30971688679247|
# |    6| 72.4953774245283|
# |    7|74.43971943925233|
# |    8|73.02981855454546|
# |    9|72.18411785294116|
# |   10|71.57854545454543|
# |   11| 72.1110893069307|
# |   12|72.84792478301885|
# +-----+-----------------+

# %% [markdown]
# # Great Job!
